# %%
# Generate simulated temperature readings from two sensors.
# Sensor A: mean 25 C, std 3 C, 200 readings.
# Sensor B: mean 27 C, std 4.5 C, 200 readings.
# Also generate 200 timestamps uniformly from 0 to 10 seconds.
# Use np.random.default_rng with a seed = 5074.

import numpy as np
import matplotlib.pyplot as plt

rng = np.random.default_rng(seed=5074)

sensor_a = rng.normal(loc=25, scale=3, size=200)
sensor_b = rng.normal(loc=27, scale=4.5, size=200)
timestamps = rng.uniform(low=0, high=10, size=200)

print(f"Sensor A - Mean: {sensor_a.mean():.2f}C, Std: {sensor_a.std():.2f}C")
print(f"Sensor B - Mean: {sensor_b.mean():.2f}C, Std: {sensor_b.std():.2f}C")
print(f"Timestamps: {len(timestamps)} values from {timestamps[0]} to {timestamps[-1]} seconds")
# Out:
# Sensor A - Mean: 25.26C, Std: 2.82C
# Sensor B - Mean: 27.00C, Std: 4.83C
# Timestamps: 200 values from 6.136798678513773 to 7.447857895961708 seconds

# %%
plt.figure(figsize=(10, 6))
plt.scatter(timestamps, sensor_a, label='Sensor A', alpha=0.6)
plt.scatter(timestamps, sensor_b, label='Sensor B', alpha=0.6)
plt.xlabel('Time (seconds)')
plt.ylabel('Temperature (C)')
plt.title('Sensor Readings Over Time')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Scatter plot: sensor reading (y-axis) vs timestamp in seconds (x-axis).
# Color Sensor A points blue and Sensor B points orange.
# Add axis labels with units, a title, and a legend.

plt.figure(figsize=(10, 6))
plt.scatter(timestamps, sensor_a, color='blue', label='Sensor A', alpha=0.6)
plt.scatter(timestamps, sensor_b, color='orange', label='Sensor B', alpha=0.6)
plt.xlabel('Time (seconds)')
plt.ylabel('Temperature (C)')
plt.title('Sensor Readings Over Time')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Overlaid histogram of Sensor A and Sensor B temperature distributions.
# Use 30 bins, alpha=0.5 for transparency so both distributions are visible.
# Add vertical dashed lines at each sensor's mean.
# Include a legend labeling each sensor.

plt.figure(figsize=(10, 6))
plt.hist(sensor_a, bins=30, alpha=0.5, label='Sensor A', color='blue')
plt.hist(sensor_b, bins=30, alpha=0.5, label='Sensor B', color='orange')
plt.axvline(sensor_a.mean(), color='blue', linestyle='--', linewidth=2, label=f'Sensor A mean: {sensor_a.mean():.2f}C')
plt.axvline(sensor_b.mean(), color='orange', linestyle='--', linewidth=2, label=f'Sensor B mean: {sensor_b.mean():.2f}C')
plt.xlabel('Temperature (C)')
plt.ylabel('Frequency')
plt.title('Temperature Distribution: Sensor A vs Sensor B')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()

# %%
# Side-by-side box plot comparing Sensor A and Sensor B distributions.
# Label x-axis with sensor names, y-axis with "Temperature (deg C)".
# Add a horizontal dashed line at the overall mean of both sensors combined.

overall_mean = np.mean(np.concatenate([sensor_a, sensor_b]))

plt.figure(figsize=(10, 6))
plt.boxplot([sensor_a, sensor_b], labels=['Sensor A', 'Sensor B'])
plt.axhline(overall_mean, color='red', linestyle='--', linewidth=2, label=f'Overall mean: {overall_mean:.2f}C')
plt.ylabel('Temperature (deg C)')
plt.title('Temperature Distribution: Sensor A vs Sensor B')
plt.legend()
plt.grid(True, alpha=0.3, axis='y')
plt.show()
# Out:
# /tmp/ipykernel_21633/1212252637.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([sensor_a, sensor_b], labels=['Sensor A', 'Sensor B'])
